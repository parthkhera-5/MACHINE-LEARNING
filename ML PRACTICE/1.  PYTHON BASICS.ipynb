# %%
a= 10
type(a)
# Out:
# int

# %%
a=10
b=20
print(a-b)
# Out:
# -10

# %%
a=10
b=20
print(a%b)
# Out:
# 10

# %%
a=10
b=22
print(b//a)
# Out:
# 2

# %%
_rk_k =22
print(_rk_k)
# Out:
# 22

# %%
a=10
b=20
if
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a<=b)
print(a>=b)
# Out:
# False
# True
# False
# True
# True
# False

# %%
a=10
b=20
if a==b:
 print("a is equal to b")
elif a!=b:
  print("a is not equal to b")
if a>b:
  print("a is greater than b")
elif a<b:
  print("a is less to b")
if a<=b:
  print("a is less than or equal to b")
elif a>=b:
  print("a is greater than or equal to b")
else:
  print("NO RELATIO FOUND!!")
# Out:
# a is not equal to b
# a is less to b
# a is less than or equal to b

# %%
A="HELLO"
B='WORLD'
print(A,B)
# Out:
# HELLO WORLD

# %%
a = "string indexing"
print(a[5],a[6],a[7])
# Out:
# g   i

# %%
# SLICING

a ="String Slicing"
# print(a[start_index : end_index : step_size])

print(a[3:9:2])
# Out:
# igS

# %%
# STRING CONCATENATION

a ='String'
b = 'Concatenation'
print(a + ' ' + b)
# Out:
# String Concatenation

# %%
# STRING CONCATENATION

a ='String'
b = 'Concatenation'
print(a*5)
# Out:
# StringStringStringStringString

# %%
# STRING CONCATENATION

a ='String'
b = 'Concatenation'
print("hello","world", "good" , "to" , "see" , "you",a,a ,sep=":")
# Out:
# hello:world:good:to:see:you:String:String

# %%
# len() - to get length
len(a)
# Out:
# 6

# %%
a="HeLlO"
print(a.lower())
a.upper()
# Out:
# hello
# 'HELLO'

# %%
a = "rahul"
a[0].upper()+a[1:5]
# Out:
# 'Rahul'

# %%
# count() - counts the repetition of the character/string
a = "hello how are you , hello how are you"
print(a.count("hello"))
# Out:
# 2

# %%
# find()
a = "we will find the index of the required using find()"
print(a.find('f'))
# Out:
# 8

# %%
# replace()
a= 'hello world'
a.replace('h','e')
# Out:
# 'eello world'

# %%
# replace the last "l" with k
a = "hello"
a.replace('lo','ko')
# Out:
# 'helko'

# %%
# f string

a = "new"
print(f'Welcome to the {a} world')
# Out:
# Welcome to the new world
