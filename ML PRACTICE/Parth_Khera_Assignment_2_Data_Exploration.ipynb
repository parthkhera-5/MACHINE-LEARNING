# %% [markdown]
# ## **Name: Parth Khera**
# ## **Class: CSE-A**
# ## **Roll No.: 169-CSE-A-23**
# ## **Enrollment No.: 35820802723**

# %% [markdown]
# # Data Exploration

# %%
#Import package
import pandas as pd
import numpy as np

# %%
path = '/content/drive/MyDrive/Colab Notebooks/data set/Copy of imdb_data.csv'
df = pd.read_csv(path)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %% [markdown]
# #Q1.Which movie made the highest profit? Who were its producer and director? Identify the actors in that film.

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df['profit'] = df['revenue'] - df['budget']

# %%
max_profit = df[df['profit'] == df['profit'].max()]
max_profit
# Out:
#         id                              belongs_to_collection     budget  \
# 1761  1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
#
#                               genres                  homepage    imdb_id  \
# 1761  [{'id': 28, 'name': 'Action'}]  http://www.furious7.com/  tt2820852
#
#      original_language original_title  \
# 1761                en      Furious 7
#
#                                                overview  popularity  ...  \
# 1761  Deckard Shaw seeks revenge against Dominic Tor...   27.275687  ...
#
#      runtime                          spoken_languages    status  \
# 1761   137.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                   tagline      title  \
# 1761  Vengeance Hits Home  Furious 7
#
#                                                Keywords  \
# 1761  [{'id': 830, 'name': 'car race'}, {'id': 3428,...
#
#                                                    cast  \
# ...

# %%
movie_name = max_profit['title'].values[0]
movie_name
# Out:
# 'Furious 7'

# %%
max_profit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 1761 to 1761
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1 non-null      int64
#  1   belongs_to_collection  1 non-null      object
#  2   budget                 1 non-null      int64
#  3   genres                 1 non-null      object
#  4   homepage               1 non-null      object
#  5   imdb_id                1 non-null      object
#  6   original_language      1 non-null      object
#  7   original_title         1 non-null      object
#  8   overview               1 non-null      object
#  9   popularity             1 non-null      float64
#  10  poster_path            1 non-null      object
#  11  production_companies   1 non-null      object
#  12  production_countries   1 non-null      object
#  13  release_date           1 non-null      object
# ...

# %%
max_profit['cast'].values[0]
# Out:
# '[{\'cast_id\': 17, \'character\': \'Dominic Toretto\', \'credit_id\': \'5431dfd10e0a265915002c34\', \'gender\': 2, \'id\': 12835, \'name\': \'Vin Diesel\', \'order\': 0, \'profile_path\': \'/7rwSXluNWZAluYMOEWBxkPmckES.jpg\'}, {\'cast_id\': 19, \'character\': "Brian O\'Conner", \'credit_id\': \'5431dfe4c3a3681143002b98\', \'gender\': 2, \'id\': 8167, \'name\': \'Paul Walker\', \'order\': 1, \'profile_path\': \'/iqvYezRoEY5k8wnlfHriHQfl5dX.jpg\'}, {\'cast_id\': 18, \'character\': \'Hobbs\', \'credit_id\': \'5431dfdbc3a36831a6004376\', \'gender\': 2, \'id\': 18918, \'name\': \'Dwayne Johnson\', \'order\': 2, \'profile_path\': \'/kuqFzlYMc2IrsOyPznMd1FroeGq.jpg\'}, {\'cast_id\': 20, \'character\': \'Letty\', \'credit_id\': \'5431dfeec3a36811ef002c75\', \'gender\': 1, \'id\': 17647, \'name\': \'Michelle Rodriguez\', \'order\': 3, \'profile_path\': \'/v37VK0MNuRuJOCKPKJcZAJXRA5r.jpg\'}, {\'cast_id\': 28, \'character\': \'Roman\', \'credit_id\': \'5431e0310e0a2656e2002c95\', \'gender\': 2
# ...

# %%
eval(max_profit['cast'].values[0])
# Out:
# [{'cast_id': 17,
#   'character': 'Dominic Toretto',
#   'credit_id': '5431dfd10e0a265915002c34',
#   'gender': 2,
#   'id': 12835,
#   'name': 'Vin Diesel',
#   'order': 0,
#   'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'},
#  {'cast_id': 19,
#   'character': "Brian O'Conner",
#   'credit_id': '5431dfe4c3a3681143002b98',
#   'gender': 2,
#   'id': 8167,
#   'name': 'Paul Walker',
#   'order': 1,
#   'profile_path': '/iqvYezRoEY5k8wnlfHriHQfl5dX.jpg'},
#  {'cast_id': 18,
#   'character': 'Hobbs',
#   'credit_id': '5431dfdbc3a36831a6004376',
#   'gender': 2,
#   'id': 18918,
#   'name': 'Dwayne Johnson',
#   'order': 2,
#   'profile_path': '/kuqFzlYMc2IrsOyPznMd1FroeGq.jpg'},
#  {'cast_id': 20,
#   'character': 'Letty',
#   'credit_id': '5431dfeec3a36811ef002c75',
#   'gender': 1,
#   'id': 17647,
#   'name': 'Michelle Rodriguez',
#   'order': 3,
#   'profile_path': '/v37VK0MNuRuJOCKPKJcZAJXRA5r.jpg'},
#  {'cast_id': 28,
#   'character': 'Roman',
# ...

# %%
for i in eval(max_profit['cast'].values[0]):
  print(i)
# Out:
# {'cast_id': 17, 'character': 'Dominic Toretto', 'credit_id': '5431dfd10e0a265915002c34', 'gender': 2, 'id': 12835, 'name': 'Vin Diesel', 'order': 0, 'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'}
# {'cast_id': 19, 'character': "Brian O'Conner", 'credit_id': '5431dfe4c3a3681143002b98', 'gender': 2, 'id': 8167, 'name': 'Paul Walker', 'order': 1, 'profile_path': '/iqvYezRoEY5k8wnlfHriHQfl5dX.jpg'}
# {'cast_id': 18, 'character': 'Hobbs', 'credit_id': '5431dfdbc3a36831a6004376', 'gender': 2, 'id': 18918, 'name': 'Dwayne Johnson', 'order': 2, 'profile_path': '/kuqFzlYMc2IrsOyPznMd1FroeGq.jpg'}
# {'cast_id': 20, 'character': 'Letty', 'credit_id': '5431dfeec3a36811ef002c75', 'gender': 1, 'id': 17647, 'name': 'Michelle Rodriguez', 'order': 3, 'profile_path': '/v37VK0MNuRuJOCKPKJcZAJXRA5r.jpg'}
# {'cast_id': 28, 'character': 'Roman', 'credit_id': '5431e0310e0a2656e2002c95', 'gender': 2, 'id': 8169, 'name': 'Tyrese Gibson', 'order': 4, 'profile_path': '/a3tyF7QXgeEH0QuEuIzNZZ8oLNS.jpg'}
# ...

# %%
for i in eval(max_profit['cast'].values[0]):
  print(i['name'])
# Out:
# Vin Diesel
# Paul Walker
# Dwayne Johnson
# Michelle Rodriguez
# Tyrese Gibson
# Ludacris
# Jordana Brewster
# Djimon Hounsou
# Tony Jaa
# Ronda Rousey
# Nathalie Emmanuel
# Kurt Russell
# Jason Statham
# Sung Kang
# Gal Gadot
# Lucas Black
# Elsa Pataky
# Noel Gugliemi
# John Brotherton
# Luke Evans
# Ali Fazal
# Miller Kimsey
# Charlie Kimsey
# Eden Estrella
# Gentry White
# Iggy Azalea
# Jon Lee Brody
# Levy Tran
# Anna Colwell
# Viktor Hernandez
# Steve Coulter
# Robert Pralgo
# Antwan Mills
# J.J. Phillips
# Jorge Ferragut
# Sara Sohn
# Benjamin Blankenship
# D.J. Hapa
# T-Pain
# Brian Mahoney
# Brittney Alger
# Romeo Santos
# Jocelin Donahue
# Stephanie Langston
# Jorge-Luis Pallo
# Tego Calderón
# Nathalie Kelley
# Shad Moss
# Don Omar
# Klement Tinaj
# Caleb Walker
# Cody Walker

# %%
actor = []

for i in eval(max_profit['cast'].values[0]):
  actor.append(i['name'])

print(actor)
# Out:
# ['Vin Diesel', 'Paul Walker', 'Dwayne Johnson', 'Michelle Rodriguez', 'Tyrese Gibson', 'Ludacris', 'Jordana Brewster', 'Djimon Hounsou', 'Tony Jaa', 'Ronda Rousey', 'Nathalie Emmanuel', 'Kurt Russell', 'Jason Statham', 'Sung Kang', 'Gal Gadot', 'Lucas Black', 'Elsa Pataky', 'Noel Gugliemi', 'John Brotherton', 'Luke Evans', 'Ali Fazal', 'Miller Kimsey', 'Charlie Kimsey', 'Eden Estrella', 'Gentry White', 'Iggy Azalea', 'Jon Lee Brody', 'Levy Tran', 'Anna Colwell', 'Viktor Hernandez', 'Steve Coulter', 'Robert Pralgo', 'Antwan Mills', 'J.J. Phillips', 'Jorge Ferragut', 'Sara Sohn', 'Benjamin Blankenship', 'D.J. Hapa', 'T-Pain', 'Brian Mahoney', 'Brittney Alger', 'Romeo Santos', 'Jocelin Donahue', 'Stephanie Langston', 'Jorge-Luis Pallo', 'Tego Calderón', 'Nathalie Kelley', 'Shad Moss', 'Don Omar', 'Klement Tinaj', 'Caleb Walker', 'Cody Walker']

# %%
max_profit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 1761 to 1761
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1 non-null      int64
#  1   belongs_to_collection  1 non-null      object
#  2   budget                 1 non-null      int64
#  3   genres                 1 non-null      object
#  4   homepage               1 non-null      object
#  5   imdb_id                1 non-null      object
#  6   original_language      1 non-null      object
#  7   original_title         1 non-null      object
#  8   overview               1 non-null      object
#  9   popularity             1 non-null      float64
#  10  poster_path            1 non-null      object
#  11  production_companies   1 non-null      object
#  12  production_countries   1 non-null      object
#  13  release_date           1 non-null      object
# ...

# %%
max_profit['crew'].values[0]
# Out:
# '[{\'credit_id\': \'52fe4cc8c3a36847f823e681\', \'department\': \'Production\', \'gender\': 2, \'id\': 12835, \'job\': \'Producer\', \'name\': \'Vin Diesel\', \'profile_path\': \'/7rwSXluNWZAluYMOEWBxkPmckES.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e687\', \'department\': \'Production\', \'gender\': 2, \'id\': 11874, \'job\': \'Producer\', \'name\': \'Neal H. Moritz\', \'profile_path\': \'/cNcsEYmoS4niCz3UkVAA09dUIob.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e68d\', \'department\': \'Writing\', \'gender\': 2, \'id\': 58191, \'job\': \'Writer\', \'name\': \'Chris Morgan\', \'profile_path\': \'/dUGxIwFBLrSFLImxjeda1krndMO.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e693\', \'department\': \'Writing\', \'gender\': 0, \'id\': 8162, \'job\': \'Characters\', \'name\': \'Gary Scott Thompson\', \'profile_path\': \'/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg\'}, {\'credit_id\': \'52fe4cc8c3a36847f823e699\', \'department\': \'Directing\', \'gender\': 2, \'id\': 2127, \'job\': \'Director\', \'n
# ...

# %%
eval(max_profit['crew'].values[0])
# Out:
# [{'credit_id': '52fe4cc8c3a36847f823e681',
#   'department': 'Production',
#   'gender': 2,
#   'id': 12835,
#   'job': 'Producer',
#   'name': 'Vin Diesel',
#   'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e687',
#   'department': 'Production',
#   'gender': 2,
#   'id': 11874,
#   'job': 'Producer',
#   'name': 'Neal H. Moritz',
#   'profile_path': '/cNcsEYmoS4niCz3UkVAA09dUIob.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e68d',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 58191,
#   'job': 'Writer',
#   'name': 'Chris Morgan',
#   'profile_path': '/dUGxIwFBLrSFLImxjeda1krndMO.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e693',
#   'department': 'Writing',
#   'gender': 0,
#   'id': 8162,
#   'job': 'Characters',
#   'name': 'Gary Scott Thompson',
#   'profile_path': '/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg'},
#  {'credit_id': '52fe4cc8c3a36847f823e699',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 2127,
# ...

# %%
for i in eval(max_profit['crew'].values[0]):
  print(i)
# Out:
# {'credit_id': '52fe4cc8c3a36847f823e681', 'department': 'Production', 'gender': 2, 'id': 12835, 'job': 'Producer', 'name': 'Vin Diesel', 'profile_path': '/7rwSXluNWZAluYMOEWBxkPmckES.jpg'}
# {'credit_id': '52fe4cc8c3a36847f823e687', 'department': 'Production', 'gender': 2, 'id': 11874, 'job': 'Producer', 'name': 'Neal H. Moritz', 'profile_path': '/cNcsEYmoS4niCz3UkVAA09dUIob.jpg'}
# {'credit_id': '52fe4cc8c3a36847f823e68d', 'department': 'Writing', 'gender': 2, 'id': 58191, 'job': 'Writer', 'name': 'Chris Morgan', 'profile_path': '/dUGxIwFBLrSFLImxjeda1krndMO.jpg'}
# {'credit_id': '52fe4cc8c3a36847f823e693', 'department': 'Writing', 'gender': 0, 'id': 8162, 'job': 'Characters', 'name': 'Gary Scott Thompson', 'profile_path': '/e2dMfqFvRsOXgWZ1VToYLmos17y.jpg'}
# {'credit_id': '52fe4cc8c3a36847f823e699', 'department': 'Directing', 'gender': 2, 'id': 2127, 'job': 'Director', 'name': 'James Wan', 'profile_path': '/d1LSKfzi5J6QngWS7niN1zPJdud.jpg'}
# ...

# %%
director = []
for i in eval(max_profit['crew'].values[0]):
  if i['job'] == 'Director':
    director.append(i['name'])

director
# Out:
# ['James Wan']

# %%
producer = []
for i in eval(max_profit['crew'].values[0]):
  if i['job'] == 'Producer':
    producer.append(i['name'])

producer
# Out:
# ['Vin Diesel', 'Neal H. Moritz', 'Michael Fottrell', 'Brandon Birtell']

# %%
print("The movie with highest profit is:", movie_name)
print("The actors in the highest profit movie are:", actor)
print("The director in the highest profit movie are:", director)
print("The actorproducers in the highest profit movie are:", producer)
# Out:
# The movie with highest profit is: Furious 7
# The actors in the highest profit movie are: ['Vin Diesel', 'Paul Walker', 'Dwayne Johnson', 'Michelle Rodriguez', 'Tyrese Gibson', 'Ludacris', 'Jordana Brewster', 'Djimon Hounsou', 'Tony Jaa', 'Ronda Rousey', 'Nathalie Emmanuel', 'Kurt Russell', 'Jason Statham', 'Sung Kang', 'Gal Gadot', 'Lucas Black', 'Elsa Pataky', 'Noel Gugliemi', 'John Brotherton', 'Luke Evans', 'Ali Fazal', 'Miller Kimsey', 'Charlie Kimsey', 'Eden Estrella', 'Gentry White', 'Iggy Azalea', 'Jon Lee Brody', 'Levy Tran', 'Anna Colwell', 'Viktor Hernandez', 'Steve Coulter', 'Robert Pralgo', 'Antwan Mills', 'J.J. Phillips', 'Jorge Ferragut', 'Sara Sohn', 'Benjamin Blankenship', 'D.J. Hapa', 'T-Pain', 'Brian Mahoney', 'Brittney Alger', 'Romeo Santos', 'Jocelin Donahue', 'Stephanie Langston', 'Jorge-Luis Pallo', 'Tego Calderón', 'Nathalie Kelley', 'Shad Moss', 'Don Omar', 'Klement Tinaj', 'Caleb Walker', 'Cody Walker']
# ...

# %% [markdown]
# #Q2.This data has information about movies made in different languages. Which language has the highest average ROI (return on investment)?

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue  \
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09
#
#              profit
# count  3.000000e+03
# mean   4.419452e+07
# std    1.123274e+08
# min   -1.074474e+08
# 25%    1.795200e+04
# 50%    6.121122e+06
# 75%    4.143293e+07
# max    1.316249e+09

# %%
df['budget'] = df['budget'].apply(lambda x: df['budget'].median() if x < 1000 else x)
df['roi'] = (df['revenue'] - df['budget'])/df['budget']
df.groupby('original_language')['roi'].mean().sort_values(ascending=False).head(1)
# Out:
# original_language
# ko    112.991812
# Name: roi, dtype: float64

# %% [markdown]
# #Q3.Find out the unique genres of movies in this dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   float64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
not_null_genres = df[df['genres'].notnull()]
not_null_genres.isnull().sum()
# Out:
# id                          0
# belongs_to_collection    2389
# budget                      0
# genres                      0
# homepage                 2048
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      149
# production_countries       52
# release_date                0
# runtime                     2
# spoken_languages           17
# status                      0
# tagline                   591
# title                       0
# Keywords                  271
# cast                       13
# crew                       15
# revenue                     0
# profit                      0
# roi                         0
# dtype: int64

# %%
genre_list = []
for i in not_null_genres['genres'][0:]:
  for j in eval(i):
    genre_list.append(j['name'])
print(genre_list)
# Out:
# ['Comedy', 'Comedy', 'Drama', 'Family', 'Romance', 'Drama', 'Thriller', 'Drama', 'Action', 'Thriller', 'Animation', 'Adventure', 'Family', 'Horror', 'Thriller', 'Documentary', 'Action', 'Comedy', 'Music', 'Family', 'Adventure', 'Comedy', 'Music', 'Drama', 'Comedy', 'Drama', 'Comedy', 'Crime', 'Action', 'Thriller', 'Science Fiction', 'Mystery', 'Action', 'Crime', 'Drama', 'Horror', 'Thriller', 'Drama', 'Romance', 'Comedy', 'Romance', 'Action', 'Thriller', 'Crime', 'Adventure', 'Family', 'Science Fiction', 'Horror', 'Thriller', 'Thriller', 'Horror', 'Thriller', 'Mystery', 'Foreign', 'Horror', 'Comedy', 'Comedy', 'Horror', 'Mystery', 'Thriller', 'Crime', 'Drama', 'Mystery', 'Thriller', 'Drama', 'Comedy', 'Romance', 'Animation', 'Action', 'Adventure', 'Crime', 'Thriller', 'Drama', 'Comedy', 'Mystery', 'Drama', 'Thriller', 'Fantasy', 'Action', 'Adventure', 'Horror', 'Action', 'Comedy', 'Crime', 'Thriller', 'Action', 'Crime', 'Thriller', 'Comedy', 'Romance', 'Action', 'Drama', 'Science Fic
# ...

# %%
set(genre_list)
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Foreign',
#  'History',
#  'Horror',
#  'Music',
#  'Mystery',
#  'Romance',
#  'Science Fiction',
#  'TV Movie',
#  'Thriller',
#  'War',
#  'Western'}

# %% [markdown]
# #Q5.Which actor has acted in the most number of movies? Deep dive into the movies, genres and profits corresponding to this actor.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   float64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
from collections import Counter
counter=Counter()
for it in df['cast'].dropna():
  for name in eval(it):
    counter[name['name']]+=1
counter.most_common(1)
best_actor=counter.most_common(1)[0][0]
print("Actor with most number of movies : ",best_actor)
print("Number of movies : ",counter.most_common(1)[0][1])
# Out:
# Actor with most number of movies :  Samuel L. Jackson
# Number of movies :  30

# %%
#Details of all movies actor is in
best_actor_movies=df[df['cast'].apply(lambda x:pd.notna(x) and best_actor in x)]
best_actor_movies
# Out:
#         id                              belongs_to_collection       budget  \
# 29      30                                                NaN   45000000.0
# 47      48                                                NaN   44000000.0
# 642    643                                                NaN   39000000.0
# 689    690  [{'id': 10, 'name': 'Star Wars Collection', 'p...  113000000.0
# 1055  1056                                                NaN    8000000.0
# 1126  1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000.0
# 1181  1182                                                NaN   85000000.0
# 1426  1427  [{'id': 495, 'name': 'Shaft Collection', 'post...   46000000.0
# 1482  1483                                                NaN   33000000.0
# 1585  1586                                                NaN    8000000.0
# 1717  1718  [{'id': 5547, 'name': 'RoboCop Collection', 'p...  120000000.0
# ...

# %%
#genres
best_actor_movies=best_actor_movies.copy()
best_actor_movies['genre_names']=best_actor_movies['genres'].apply(lambda x: " ".join(it['name'] for it in eval(x)))
best_actor_movies[['original_title','genre_names','release_date','budget','revenue','profit']]
# Out:
#                                     original_title  \
# 29                                  Changing Lanes
# 47                               The Hateful Eight
# 642                              Coming to America
# 689   Star Wars: Episode III - Revenge of the Sith
# 1055                                  Meeting Evil
# 1126                                  The Avengers
# 1181                                        Jumper
# 1426                                         Shaft
# 1482                             Snakes on a Plane
# 1585                                       The Man
# 1717                                       RoboCop
# 1735                                 Jurassic Park
# 1773                                          Cell
# 1818  Star Wars: Episode II - Attack of the Clones
# 1853                              Eddie Murphy Raw
# 1861           Captain America: The Winter Soldier
# 1916                                  Jackie Brown
# ...

# %%
#most profitable movie
best_actor_movies[['original_title','profit']].sort_values('profit',ascending=False).head(1)
# Out:
#      original_title      profit
# 1126   The Avengers  1299557910

# %%
print("Least profitable movie :")
best_actor_movies[['original_title','profit']].sort_values('profit',ascending=True).head(1)
# Out:
# Least profitable movie :
#      original_title    profit
# 2985    Freedomland -23009372

# %%
#most repeated genre

genres=[]
for genre in best_actor_movies['genre_names']:
  genres.append(genre.split())
counter=Counter()
for g in genres:
  for it in g:
    counter[it]+=1
counter.most_common(1)
print(best_actor)
print("Most repeated genre : ",counter.most_common(1)[0][0])
print("Number of movies : ",counter.most_common(1)[0][1])
# Out:
# Samuel L. Jackson
# Most repeated genre :  Action
# Number of movies :  17

# %%
best_actor_movies['release_date'].head()
# Out:
# 29        4/7/02
# 47      12/25/15
# 642      6/28/88
# 689      5/17/05
# 1055      5/3/12
# Name: release_date, dtype: object

# %%
#movies across years
best_actor_movies=best_actor_movies.copy()
best_actor_movies['release_year']=pd.to_datetime(best_actor_movies['release_date'],format='%m/%d/%y',errors='coerce').dt.year
best_actor_movies.groupby(best_actor_movies['release_year']).size()
# Out:
# release_year
# 1987    1
# 1988    1
# 1989    1
# 1992    1
# 1993    1
# 1996    1
# 1997    1
# 1998    1
# 1999    1
# 2000    1
# 2002    2
# 2003    2
# 2004    1
# 2005    2
# 2006    3
# 2008    1
# 2011    1
# 2012    2
# 2014    3
# 2015    2
# 2016    1
# dtype: int64

# %%
best_actor_movies.groupby(best_actor_movies['release_year']).size().plot(
    kind='bar',
    color = 'green',
    figsize=(16,6),
    title=f'{best_actor} Movies per year',
    xlabel='release_years',
    ylabel='number_of_movies'
)
# Out:
# <Axes: title={'center': 'Samuel L. Jackson Movies per year'}, xlabel='release_years', ylabel='number_of_movies'>
